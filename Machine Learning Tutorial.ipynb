# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
tr = pd.read_csv('C:/Users/Nikhil/Downloads/train.csv')
tr
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
tr.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
y = tr[['SalePrice']]
x = tr[['LotArea','YearBuilt','1stFlrSF','2ndFlrSF','FullBath','BedroomAbvGr','TotRmsAbvGrd']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dr = DecisionTreeRegressor()

# %%
dr.fit(x,y)
# Out:
# DecisionTreeRegressor()

# %%
y_predict = dr.predict(x.head())
y_predict
# Out:
# array([208500., 181500., 223500., 140000., 250000.])

# %%
dr = DecisionTreeRegressor(random_state=1)

# %%
dr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
y_predict=dr.predict(x_test)
y_predict
# Out:
# array([335000., 205000., 124000., 205000.,  89500.,  58500., 350000.,
#        113000., 755000., 147576., 213500., 150900., 210000., 125500.,
#        142125., 153000., 236000., 126000., 151000., 128000., 135000.,
#        149000.,  62383., 185000., 139000., 138887., 195000.,  92000.,
#        326000., 105500., 118000., 196500.,  99500., 258000., 377500.,
#        168500., 234000., 111250., 222500., 315750., 244000., 130000.,
#        185500., 236500., 267000., 125000., 107500., 144000., 179900.,
#        128500., 315750., 154500., 196000., 113000., 193000., 120500.,
#        153575., 190000.,  93000.,  87000., 126500., 150000., 140000.,
#        141000., 262000., 144500., 129000., 210000., 107400., 208500.,
#        189000., 142125., 139000., 250580., 135750., 284000., 131500.,
#         76000., 325300., 161500., 143000., 134900.,  58500., 147000.,
#        274970., 176000.,  79000., 202500., 198900., 109000., 216000.,
# ...

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 32767.703196347033

# %%
MAE1 = []
for i in range(0,5):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leafs_nodes[i], random_state=0)
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)
    model.fit(x_train,y_train)
    preds_val = model.predict(x_test)
    MAE = mean_absolute_error(y_test, preds_val)
    MAE1.append(MAE)

# %%
max_leafs_nodes = [5, 25, 50, 100, 250, 500]

# %%
max_leafs_nodes[0]
# Out:
# 5

# %%
MAE1
# Out:
# [34835.49253249091,
#  28100.092926645324,
#  28522.12328974183,
#  29695.55176545459,
#  31834.79264590686]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(random_state=1)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=1)

# %%
rf_predict = rf.predict(x_test)
rf_predict
# Out:
# array([279125.        , 161878.68      , 121501.64      , 194837.        ,
#         88203.        ,  85494.93      , 240796.95      , 124602.59      ,
#        625507.33      , 169941.28266667, 200164.8       , 154883.916     ,
#        229488.35      , 123700.        , 135808.25      , 135057.        ,
#        237219.6       , 133214.        , 150386.87      , 129147.71      ,
#        126116.18      , 146153.33333333, 107214.86      , 183427.31      ,
#        157838.5       , 153147.88      , 176983.        ,  88502.        ,
#        325057.37      , 106243.02      , 139285.        , 190615.        ,
#        123536.625     , 284773.63      , 363412.17      , 180438.75      ,
#        223716.83      , 115481.5       , 224282.78      , 295766.01      ,
#        220652.        , 141525.75666667, 185989.76      , 295294.95      ,
#        303918.83      , 142075.        , 103195.32      , 127630.5       ,
# ...

# %%
rf_mae = mean_absolute_error(y_test,rf_predict)
rf_mae
# Out:
# 23175.58262970211

# %%
te = pd.read_csv('C:/Users/Nikhil/Downloads/test.csv')
te
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
tr = pd.read_csv('C:/Users/Nikhil/Downloads/train.csv',index_col='Id')
tr
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
z = te[['LotArea','YearBuilt','1stFlrSF','2ndFlrSF','FullBath','BedroomAbvGr','TotRmsAbvGrd']]

# %%
model_1 = RandomForestRegressor(n_estimators=50, random_state=0)
model_2 = RandomForestRegressor(n_estimators=100, random_state=0)
model_3 = RandomForestRegressor(n_estimators=150, random_state=0)
model_4 = RandomForestRegressor(n_estimators=200, min_samples_split=20, random_state=0)
model_5 = RandomForestRegressor(n_estimators=100, max_depth=7, random_state=0)

model = [model_1,model_2,model_3,model_4,model_5]

# %%
MAE2 = []
for i in model:
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)
    i.fit(x_train,y_train)
    preds_val = i.predict(x_test)
    MAE3 = mean_absolute_error(y_test,preds_val)
    MAE2.append(MAE3)

# %%
MAE2
# Out:
# [24015.492818003917,
#  23740.979228636657,
#  23752.723268101763,
#  23996.676789668687,
#  23706.672864217904]

# %%
my_model = model_2

# %%
my_model.fit(x,y)
# Out:
# RandomForestRegressor(random_state=0)

# %%
predict_test = my_model.predict(z)
predict_test
# Out:
# array([121501.  , 154652.  , 182625.  , ..., 160942.02, 127412.  ,
#        223235.35])

# %% [markdown]
# # Missing Values

# %%
tr.isna().sum()
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 80, dtype: int64

# %%
b = tr.dropna(axis=0,subset=['SalePrice'])

# %%
x1 = b.drop('SalePrice',axis=1)
y1 = b[['SalePrice']]

# %%
x2 = b.select_dtypes(exclude=['object'])
z2 =te.select_dtypes(exclude=['object'])

# %%
x_train,x_test,y_train,y_test = train_test_split(x2,y1,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (1168, 37)

# %%
missing_value_count = x_train.isna().sum()

# %%
missed = missing_value_count[missing_value_count > 0]
missed
# Out:
# LotFrontage    212
# MasVnrArea       6
# GarageYrBlt     58
# dtype: int64

# %%
row = x_train.shape[0]
row
# Out:
# 1168

# %%
missed.count()
# Out:
# 3

# %%
missed.sum()
# Out:
# 276

# %%
reduced_X_train = x_train.dropna(axis=1)
reduced_X_train
# Out:
#       MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id
# 619           20    11694            9            5       2007          2007
# 871           20     6600            5            5       1962          1962
# 93            30    13360            5            7       1921          2006
# 818           20    13265            8            5       2002          2002
# 303           20    13704            7            5       2001          2002
# ...          ...      ...          ...          ...        ...           ...
# 764           60     9430            8            5       1999          1999
# 836           20     9600            4            7       1950          1995
# 1217          90     8930            6            5       1978          1978
# 560          120     3196            7            5       2003          2004
# 685           60    16770            7            5       1998          1998
#
# ...

# %%
reduced_X_test = x_test.dropna(axis=1)
reduced_X_test
# Out:
#       MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id
# 530           20    32668            6            3       1957          1975
# 492           50     9490            6            7       1941          1950
# 460           50     7015            5            4       1950          1950
# 280           60    10005            7            5       1977          1977
# 656          160     1680            6            5       1971          1971
# ...          ...      ...          ...          ...        ...           ...
# 327          120    10846            8            5       1993          1993
# 441           20    15431           10            5       2008          2008
# 1388          50     8520            6            7       1916          1950
# 1324          30     5330            4            7       1940          1950
# 62            75     7200            5            7       1920          1996
#
# ...

# %%
model = RandomForestRegressor(n_estimators=100, random_state=0)

# %%
model.fit(reduced_X_train,y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
preds = model.predict(reduced_X_test)
preds
# Out:
# array([200749.92, 132999.  , 110018.  , 192246.6 ,  87875.  ,  84942.  ,
#        283817.99, 141217.  , 646458.4 , 149005.  , 208918.  , 136930.5 ,
#        224904.  , 122974.  , 118950.58, 144974.  , 189999.5 , 123790.  ,
#        149423.  , 155027.45, 165722.3 , 144405.1 , 110010.5 , 173956.99,
#        185010.  , 168006.4 , 177301.45,  84632.  , 319197.72, 118420.64,
#        109926.88, 213155.  , 155873.89, 250182.7 , 374014.51, 174976.18,
#        276972.  , 112222.5 , 263024.17, 326068.32, 242117.28, 129982.  ,
#        164976.  , 280079.82, 402543.71, 118930.98, 124984.  , 128045.  ,
#        172466.7 ,  84761.  , 404454.34, 155890.85, 167880.  , 100004.76,
#        274955.05, 122874.  , 131963.5 , 239941.86, 138974.87, 114995.04,
#        137535.5 , 135000.  , 134441.34, 180557.34, 192974.  , 156657.85,
#        131995.5 , 224610.  , 138929.53, 224966.  , 188497.  , 117990.  ,
#         81400.  , 394175.61, 112055.  , 248617.86, 134537.2 ,  79949.  ,
# ...

# %%
mean_absolute_error(y_test,preds)
# Out:
# 909.0415068493146

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer()

# %%
x_train['LotFrontage'] = x_train['LotFrontage'].fillna(x_train['LotFrontage'].mean())

# %%
x_train['MasVnrArea'] = x_train['MasVnrArea'].fillna(x_train['MasVnrArea'].mean())

# %%
x_train['GarageYrBlt'] = x_train['GarageYrBlt'].fillna(x_train['GarageYrBlt'].mean())

# %%
test_miss = x_test.isna().sum()
test_miss[test_miss > 0]
# Out:
# LotFrontage    47
# MasVnrArea      2
# GarageYrBlt    23
# dtype: int64

# %% [markdown]
# # Categorical Variables

# %%
X = x2.dropna(axis=1)

# %%
tr
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
y1
# Out:
#       SalePrice
# Id
# 1        208500
# 2        181500
# 3        223500
# 4        140000
# 5        250000
# ...         ...
# 1456     175000
# 1457     210000
# 1458     266500
# 1459     142125
# 1460     147500
#
# [1460 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x = tr.drop('SalePrice',axis=1)
y=tr[['SalePrice']]

# %%
x1 = x.select_dtypes(exclude='object')
x1_test = te.select_dtypes(exclude='object')

# %%
x_train,x_test,y_train,y_test = train_test_split(x1,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (1168, 37)

# %%
missed = x_train.isna().sum()

# %%
missing_values = missed[missed > 0]
missing_values
# Out:
# LotFrontage    212
# MasVnrArea       6
# GarageYrBlt     58
# dtype: int64

# %%
missing_values.sum()
# Out:
# 276

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
def score_dataset(x_train,x_test, y_train, y_test):
    model = RandomForestRegressor(n_estimators=100, random_state=0)
    model.fit(x_train, y_train)
    preds = model.predict(x_test)
    return mean_absolute_error(y_test, preds)

# %%
# MAE Value by dropping missing values column
reduced_x_train = x_train.dropna(axis=1)

# %%
reduced_x_test = x_test.dropna(axis=1)

# %%
print('MAE:',score_dataset(reduced_x_train,reduced_x_test,y_train,y_test))
# Out:
# MAE: 17952.591404109586

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer()

# %%
# MAE value by implementing simpleImputer 
imputed_x_train = pd.DataFrame(si.fit_transform(x_train))
imputed_x_train
# Out:
#           0      1           2        3    4    5       6       7      8   \
# 0      619.0   20.0   90.000000  11694.0  9.0  5.0  2007.0  2007.0  452.0
# 1      871.0   20.0   60.000000   6600.0  5.0  5.0  1962.0  1962.0    0.0
# 2       93.0   30.0   80.000000  13360.0  5.0  7.0  1921.0  2006.0    0.0
# 3      818.0   20.0   69.614017  13265.0  8.0  5.0  2002.0  2002.0  148.0
# 4      303.0   20.0  118.000000  13704.0  7.0  5.0  2001.0  2002.0  150.0
# ...      ...    ...         ...      ...  ...  ...     ...     ...    ...
# 1163   764.0   60.0   82.000000   9430.0  8.0  5.0  1999.0  1999.0  673.0
# 1164   836.0   20.0   60.000000   9600.0  4.0  7.0  1950.0  1995.0    0.0
# 1165  1217.0   90.0   68.000000   8930.0  6.0  5.0  1978.0  1978.0    0.0
# 1166   560.0  120.0   69.614017   3196.0  7.0  5.0  2003.0  2004.0   18.0
# 1167   685.0   60.0   58.000000  16770.0  7.0  5.0  1998.0  1998.0   30.0
#
#           9   ...     27     28     29    30   31     32   33   34    35  \
# ...

# %%
imputed_x_test = pd.DataFrame(si.transform(x_test))
imputed_x_test
# Out:
#          0      1           2        3     4    5       6       7   \
# 0     530.0   20.0   69.614017  32668.0   6.0  3.0  1957.0  1975.0
# 1     492.0   50.0   79.000000   9490.0   6.0  7.0  1941.0  1950.0
# 2     460.0   50.0   69.614017   7015.0   5.0  4.0  1950.0  1950.0
# 3     280.0   60.0   83.000000  10005.0   7.0  5.0  1977.0  1977.0
# 4     656.0  160.0   21.000000   1680.0   6.0  5.0  1971.0  1971.0
# ..      ...    ...         ...      ...   ...  ...     ...     ...
# 287   327.0  120.0   32.000000  10846.0   8.0  5.0  1993.0  1993.0
# 288   441.0   20.0  105.000000  15431.0  10.0  5.0  2008.0  2008.0
# 289  1388.0   50.0   60.000000   8520.0   6.0  7.0  1916.0  1950.0
# 290  1324.0   30.0   50.000000   5330.0   4.0  7.0  1940.0  1950.0
# 291    62.0   75.0   60.000000   7200.0   5.0  7.0  1920.0  1996.0
#
#              8       9   ...     27     28     29     30   31     32   33  \
# 0    103.481067  1219.0  ...  484.0    0.0    0.0  200.0  0.0    0.0  0.0
# ...

# %%
imputed_x_train.columns = x_train.columns
imputed_x_test.columns = x_test.columns

# %%
print('MAE-Imputed:',score_dataset(imputed_x_train,imputed_x_test,y_train,y_test))
# Out:
# MAE-Imputed: 18250.608013698627

# %%
l = missing_values.reset_index()['index'].unique()
l.tolist()
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
x_train_plus = x_train.copy
x_test_plus = x_test.copy

# %%
for col in l.tolist():
    p = x_train_plus[col].isnull()
    x_train_plus[col + 'missing'] = p
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34192/1848760916.py in <module>
#       1 for col in l.tolist():
# ----> 2     p = x_train_plus[col].isnull()
#       3     x_train_plus[col + 'missing'] = p
#
# TypeError: 'method' object is not subscriptable

# %%
cols_with_missing = [col for col in x_train.columns
                     if x_train[col].isnull().any()]

# %%
cols_with_missing
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %% [markdown]
# # Categorical Variable

# %%
X = x.dropna(axis=1)

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
x_train['Condition2'].unique()
# Out:
# array(['Norm', 'PosA', 'Feedr', 'PosN', 'Artery', 'RRAe'], dtype=object)

# %%
object_col = x_train.select_dtypes(include='object').columns
object_cols = object_col.tolist()
object_cols
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'KitchenQual',
#  'Functional',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
good_label_cols = [col for col in object_cols if 
                   set(x_test[col]).issubset(set(x_train[col]))]

# %%
good_label_cols
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'Exterior1st',
#  'Exterior2nd',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'KitchenQual',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
set(x_test['Street']).issubset(set(x_train['Street']))
# Out:
# True

# %%
bad_label_cols = list(set(object_cols)-set(good_label_cols))

# %%
bad_label_cols
# Out:
# ['Functional', 'RoofMatl', 'Condition2']

# %%
label_x_train = x_train.drop(bad_label_cols,axis=1)
label_x_test = x_test.drop(bad_label_cols, axis=1)

# %%
label_x_train
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 618    619          20       RL    11694   Pave      Reg         Lvl
# 870    871          20       RL     6600   Pave      Reg         Lvl
# 92      93          30       RL    13360   Pave      IR1         HLS
# 817    818          20       RL    13265   Pave      IR1         Lvl
# 302    303          20       RL    13704   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 763    764          60       RL     9430   Pave      Reg         Lvl
# 835    836          20       RL     9600   Pave      Reg         Lvl
# 1216  1217          90       RM     8930   Pave      Reg         Lvl
# 559    560         120       RL     3196   Pave      Reg         Lvl
# 684    685          60       RL    16770   Pave      IR2         Lvl
#
#      Utilities LotConfig LandSlope  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ol = OrdinalEncoder()

# %%
label_x_train[good_label_cols] = ol.fit_transform(label_x_train[good_label_cols])

# %%
label_x_train
# Out:
#         Id  MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  \
# 618    619          20       3.0    11694     1.0       3.0          3.0
# 870    871          20       3.0     6600     1.0       3.0          3.0
# 92      93          30       3.0    13360     1.0       0.0          1.0
# 817    818          20       3.0    13265     1.0       0.0          3.0
# 302    303          20       3.0    13704     1.0       0.0          3.0
# ...    ...         ...       ...      ...     ...       ...          ...
# 763    764          60       3.0     9430     1.0       3.0          3.0
# 835    836          20       3.0     9600     1.0       3.0          3.0
# 1216  1217          90       4.0     8930     1.0       3.0          3.0
# 559    560         120       3.0     3196     1.0       3.0          3.0
# 684    685          60       3.0    16770     1.0       1.0          3.0
#
#       Utilities  LotConfig  LandSlope  ...  OpenPorchSF  EnclosedPorch  \
# ...

# %%
label_x_test[good_label_cols] = ol.transform(label_x_test[good_label_cols])

# %%
label_x_test
# Out:
#         Id  MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  \
# 529    530          20       3.0    32668     1.0       0.0          3.0
# 491    492          50       3.0     9490     1.0       3.0          3.0
# 459    460          50       3.0     7015     1.0       0.0          0.0
# 279    280          60       3.0    10005     1.0       3.0          3.0
# 655    656         160       4.0     1680     1.0       3.0          3.0
# ...    ...         ...       ...      ...     ...       ...          ...
# 326    327         120       3.0    10846     1.0       0.0          3.0
# 440    441          20       3.0    15431     1.0       3.0          3.0
# 1387  1388          50       4.0     8520     1.0       3.0          3.0
# 1323  1324          30       3.0     5330     1.0       3.0          1.0
# 61      62          75       4.0     7200     1.0       3.0          3.0
#
#       Utilities  LotConfig  LandSlope  ...  OpenPorchSF  EnclosedPorch  \
# ...

# %%
print('MAE-ordinal_encoding:',score_dataset(label_x_train,label_x_test,y_train,y_test))
# Out:
# MAE-ordinal_encoding: 17251.037739726027

# %%
low_cardinality_cols = []
for i in object_cols:
    h = x_train[i].unique().size
    if h < 10:
        low_cardinality_cols.append(i)

# %%
low_cardinality_cols
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'KitchenQual',
#  'Functional',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
high_cardinality_cols = list(set(object_cols)-set(low_cardinality_cols))
high_cardinality_cols
# Out:
# ['Exterior2nd', 'Exterior1st', 'Neighborhood']

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
oh = OneHotEncoder(handle_unknown='ignore', sparse=False)

# %%
oh_x_train = pd.DataFrame(oh.fit_transform(x_train[low_cardinality_cols]))
oh_x_test = pd.DataFrame(oh.transform(x_test[low_cardinality_cols]))

# %%
oh_x_train.index = x_train.index

# %%
oh_x_test.index = x_test.index

# %%
num_x_train = x_train.drop(object_cols,axis=1)
num_x_test = x_test.drop(object_cols,axis=1)

# %%
OH_x_train = pd.concat([num_x_train,oh_x_train],axis=1)

# %%
OH_x_test = pd.concat([num_x_test,oh_x_test])

# %%
OH_x_train1 = OH_x_train.fillna(0)
OH_x_test2 = OH_x_test.fillna(0)

# %%
OH_x_train1.shape
# Out:
# (1168, 156)

# %%
OH_x_test2.shape
# Out:
# (584, 156)

# %%
y_test.shape
# Out:
# (292, 1)

# %%
print('MAE-Onehotencoding:',score_dataset(OH_x_train1,OH_x_test2,y_train,y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34192/2642728468.py in <module>
# ----> 1 print('MAE-Onehotencoding:',score_dataset(OH_x_train1,OH_x_test2,y_train,y_test))
#
# ~\AppData\Local\Temp/ipykernel_34192/428878385.py in score_dataset(x_train, x_test, y_train, y_test)
#       3     model.fit(x_train, y_train)
#       4     preds = model.predict(x_test)
# ----> 5     return mean_absolute_error(y_test, preds)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
# ...

# %% [markdown]
# # Pipelines

# %%
x_train_num = x_train.select_dtypes('int64','float64')

# %%
x_train_num1
# Out:
# ['Id',
#  'MSSubClass',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %%
cat_x_train = low_cardinality_cols.copy()
cat_x_train
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'KitchenQual',
#  'Functional',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
my_cols = cat_x_train + x_train_num1

# %%
catagorical_col = [cname for cname in x_train.columns if x_train[cname].nunique() < 10 and x_train[cname].dtype=='object' ]
catagorical_col
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'KitchenQual',
#  'Functional',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
numerical_col = [cname for cname in x_train.columns if x_train[cname].dtype in ['int64','float32']]
numerical_col
# Out:
# ['Id',
#  'MSSubClass',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %%
my_col = catagorical_col + numerical_col

# %%
x_train1 = x_train[my_col].copy()
x_test1 = x_test[my_col].copy()

# %%
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
num_pre = SimpleImputer(strategy='constant')

# %%
cat_pre = Pipeline(steps=[('impute',SimpleImputer(strategy='most_frequent')),('onehot',OneHotEncoder(handle_unknown='ignore'))])

# %%
preprocessor = ColumnTransformer(transformers=[('num',num_pre,numerical_col),('cat',cat_pre,catagorical_col)])

# %%
model = RandomForestRegressor(n_estimators=100, random_state=0)

# %%
my_pipeline = Pipeline(steps=[('preprocessor',preprocessor),('model',model)])

# %%
my_pipeline.fit(x_train1,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   SimpleImputer(strategy='constant'),
#                                                   ['Id', 'MSSubClass',
#                                                    'LotArea', 'OverallQual',
#                                                    'OverallCond', 'YearBuilt',
#                                                    'YearRemodAdd', 'BsmtFinSF1',
#                                                    'BsmtFinSF2', 'BsmtUnfSF',
#                                                    'TotalBsmtSF', '1stFlrSF',
#                                                    '2ndFlrSF', 'LowQualFinSF',
#                                                    'GrLivArea', 'BsmtFullBath',
#                                                    'BsmtHalfBath', 'FullBath',
#                                                    'HalfBath', 'Bedroo...
# ...

# %%
preds = my_pipeline.predict(x_test1)

# %%
mean_absolute_error(y_test,preds)
# Out:
# 17514.224246575344

# %% [markdown]
# # Cross Validation

# %%
X1 =X[numerical_col].copy()

# %%
my_pipeline1 = Pipeline(steps=[('preprocessor',SimpleImputer()),('model',RandomForestRegressor(n_estimators=50, random_state=0))])

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = -1*cross_val_score(my_pipeline1,X1,y,cv=5,scoring='neg_mean_absolute_error')

# %%
scores.mean()
# Out:
# 18223.716246575343

# %%
def get_score(n_estimatores):
    my_pipeline1 = Pipeline(steps=[('preprocessor',SimpleImputer()),('model',RandomForestRegressor(n_estimators=n_estimatores, random_state=0))])
    scores = -1*cross_val_score(my_pipeline1,X1,y,cv=5,scoring='neg_mean_absolute_error')
    return scores.mean()

# %%
get_score(150)
# Out:
# 17897.405739726026

# %%
# Data
