# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Create a dataframe matching the above diagram and assign it to the variable fruits.

fruits = pd.DataFrame(data={'Apples':[30],'Bananas':[20]})
# Out:
#    Apples  Bananas
# 0      30       20

# %%
#Create a dataframe matching the above diagram and assign it to the variable fruit_sales.

fruit_sales = pd.DataFrame(data={'Apples':[35,41],'Bananas':[21,34]},index=['2017 Sales','2018 Sales'])
fruit_sales
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %%
#Create DataFrame Ingrediants

ingrediants = pd.DataFrame(data=['4 cups','1 cup','2 large','1 can'],index=['Flour','Milk','Age','Spam'])
ingrediants
# Out:
#              0
# Flour   4 cups
# Milk     1 cup
# Age    2 large
# Spam     1 can

# %% [markdown]
# # Indexing, Selecting and Assingning

# %%
reviews = pd.read_csv('C:/Users/Nikhil/AppData/Local/Temp/Temp1_winemag-data-130k-v2.csv.zip/winemag-data-130k-v2.csv')

# %%
reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
# Select the description column from reviews and assign the result to the variable desc.
desc = reviews['description']

# %%
desc.dtype
# Out:
# dtype('O')

# %%
# Select the first value from the description column of reviews, assigning it to variable first_description

first_description = reviews['description'][0]
first_description
# Out:
# "Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity."

# %%
# Select the first row of data (the first record) from reviews, assigning it to the variable first_row.

first_row = reviews.iloc[[0]]
first_row
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0   Italy  Aromas include tropical fruit, broom, brimston...
#
#     designation  points  price           province region_1 region_2  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
#
#      taster_name taster_twitter_handle                              title  \
# 0  Kerin O’Keefe          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)
#
#        variety   winery
# 0  White Blend  Nicosia

# %%
# select the first 10 values from the description column in reviews, assigning the result to variable first_descriptions.

first_descriptions = reviews['description'].head(10)
first_descriptions
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 1    This is ripe and fruity, a wine that is smooth...
# 2    Tart and snappy, the flavors of lime flesh and...
# 3    Pineapple rind, lemon pith and orange blossom ...
# 4    Much like the regular bottling from 2012, this...
# 5    Blackberry and raspberry aromas show a typical...
# 6    Here's a bright, informal red that opens with ...
# 7    This dry and restrained wine offers spice in p...
# 8    Savory dried thyme notes accent sunnier flavor...
# 9    This has great depth of flavor with its fresh ...
# Name: description, dtype: object

# %%
# Select the records with index labels 1, 2, 3, 5, and 8, assigning the result to the variable sample_review

# %%
n = [1,2,3,5,8]

# %%
reviews.loc[[1]]
# Out:
#    Unnamed: 0   country                                        description  \
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
#
#   designation  points  price province region_1 region_2 taster_name  \
# 1    Avidagos      87   15.0    Douro      NaN      NaN  Roger Voss
#
#   taster_twitter_handle                                          title  \
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery
# 1  Portuguese Red  Quinta dos Avidagos

# %%
n1 = []
for i in n:
    n2 = reviews.loc[[i]]
    n1.append(n2)

# %%
n1
# Out:
# [   Unnamed: 0   country                                        description  \
#  1           1  Portugal  This is ripe and fruity, a wine that is smooth...
#
#    designation  points  price province region_1 region_2 taster_name  \
#  1    Avidagos      87   15.0    Douro      NaN      NaN  Roger Voss
#
#    taster_twitter_handle                                          title  \
#  1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#            variety               winery
#  1  Portuguese Red  Quinta dos Avidagos  ,
#     Unnamed: 0 country                                        description  \
#  2           2      US  Tart and snappy, the flavors of lime flesh and...
#
#    designation  points  price province           region_1           region_2  \
#  2         NaN      87   14.0   Oregon  Willamette Valley  Willamette Valley
#
#      taster_name taster_twitter_handle  \
#  2  Paul Gregutt           @paulgwine
#
# ...

# %%
# Create a variable df containing the country and variety columns of the first 100 records.
df = reviews[['country','variety']][0:100]
df
# Out:
#      country                   variety
# 0      Italy               White Blend
# 1   Portugal            Portuguese Red
# 2         US                Pinot Gris
# 3         US                  Riesling
# 4         US                Pinot Noir
# ..       ...                       ...
# 95    France                     Gamay
# 96    France                     Gamay
# 97        US                  Riesling
# 98     Italy                Sangiovese
# 99        US  Bordeaux-style Red Blend
#
# [100 rows x 2 columns]

# %%
# Create a DataFrame italian_wines containing reviews of wines made in Italy

italian_wines = reviews[reviews['country']=='Italy']['winery'].reset_index()

# %%
italian_wines
# Out:
#         index                           winery
# 0           0                          Nicosia
# 1           6                  Terre di Giurfo
# 2          13              Masseria Setteporte
# 3          22               Baglio di Pianetto
# 4          24                        Canicattì
# ...       ...                              ...
# 19535  129929             Col Vetoraz Spumanti
# 19536  129943  Baglio del Cristo di Campobello
# 19537  129947         Feudo Principi di Butera
# 19538  129961                              COS
# 19539  129962                         Cusumano
#
# [19540 rows x 2 columns]

# %%
# Create a DataFrame top_oceania_wines containing all reviews with at least 95 points (out of 100) for wines from Australia or New Zealand.

top_oceania_wines = reviews[reviews['country']=='Australia']

# %%
top_oceania_wines
# Out:
#         Unnamed: 0    country  \
# 77              77  Australia
# 83              83  Australia
# 123            123  Australia
# 191            191  Australia
# 232            232  Australia
# ...            ...        ...
# 129414      129414  Australia
# 129433      129433  Australia
# 129446      129446  Australia
# 129447      129447  Australia
# 129726      129726  Australia
#
#                                               description  \
# 77      This medium-bodied Chardonnay features aromas ...
# 83      Pale copper in hue, this wine exudes passion f...
# 123     The blend is roughly two-thirds Shiraz and one...
# 191     From the little-known region of Padthaway, thi...
# 232     Lifted cedar and pine notes interspersed with ...
# ...                                                   ...
# 129414  A bit more austere than some of Kilikanoon's o...
# 129433  This wine shows a pleasing nose of black curra...
# 129446  Black licorice, raisiny fruit and a little swe...
# ...

# %%
# What is the median of the points column in the reviews DataFrame?

median_points = reviews['points'].median()
median_points
# Out:
# 88.0

# %%
# What countries are represented in the dataset?

Countries = reviews['country'].unique
Countries
# Out:
# <bound method Series.unique of 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object>

# %%
# How often does each country appear in the dataset

reviews_per_country = reviews['country'].value_counts()
reviews_per_country
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %%
# Create variable centered_price containing a version of the price column with the mean price subtracted.

centered_price = reviews['price'] - reviews['price'].mean()
centered_price
# Out:
# 0               NaN
# 1        -20.363389
# 2        -21.363389
# 3        -22.363389
# 4         29.636611
#             ...
# 129966    -7.363389
# 129967    39.636611
# 129968    -5.363389
# 129969    -3.363389
# 129970   -14.363389
# Name: price, Length: 129971, dtype: float64

# %%
# Create a variable bargain_wine with the title of the wine with the highest points-to-price ratio in the dataset.

reviews['barain_wine'] = reviews['points']/reviews['price']

# %%
reviews['barain_wine'].max()
# Out:
# 21.5

# %%
reviews[reviews['barain_wine']==reviews['barain_wine'].max()]['title']
# Out:
# 64590                         Bandit NV Merlot (California)
# 126096    Cramele Recas 2011 UnWineD Pinot Grigio (Viile...
# Name: title, dtype: object

# %%
y = reviews['description'].str.split(' ')

# %%
reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
reviews['points'].value_counts()
# Out:
# 88     17207
# 87     16933
# 90     15410
# 86     12600
# 89     12226
# 91     11359
# 92      9613
# 85      9530
# 93      6489
# 84      6480
# 94      3758
# 83      3025
# 82      1836
# 95      1535
# 81       692
# 96       523
# 80       397
# 97       229
# 98        77
# 99        33
# 100       19
# Name: points, dtype: int64

# %%
def star(b):
    if b >= 95:
        print('3 star')
    elif b >= 85:
        print('2 star')
    elif b < 85:
        print('1 star')

# %%
reviews['points'].apply(star(b))
# Out:
# 2 star
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_63656/3161878263.py in <module>
# ----> 1 reviews['points'].apply(star(b))
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# ...

# %%
y
# Out:
# 0         [Aromas, include, tropical, fruit,, broom,, br...
# 1         [This, is, ripe, and, fruity,, a, wine, that, ...
# 2         [Tart, and, snappy,, the, flavors, of, lime, f...
# 3         [Pineapple, rind,, lemon, pith, and, orange, b...
# 4         [Much, like, the, regular, bottling, from, 201...
#                                 ...
# 129966    [Notes, of, honeysuckle, and, cantaloupe, swee...
# 129967    [Citation, is, given, as, much, as, a, decade,...
# 129968    [Well-drained, gravel, soil, gives, this, wine...
# 129969    [A, dry, style, of, Pinot, Gris,, this, is, cr...
# 129970    [Big,, rich, and, off-dry,, this, is, powered,...
# Name: description, Length: 129971, dtype: object

# %%
y.apply(lambda x:x.count('fruity')).value_counts()[1:4].sum()
# Out:
# 5935

# %%
y.apply(lambda x:x.count('tropical')).value_counts()[1:3].sum()
# Out:
# 3224

# %% [markdown]
# # Grouping and sorting

# %%
reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
reviews[['taster_twitter_handle']].value_counts().reset_index().set_index('taster_twitter_handle')
# Out:
#                            0
# taster_twitter_handle
# @vossroger             25514
# @wineschach            15134
# @kerinokeefe           10776
# @vboone                 9537
# @paulgwine              9532
# @mattkettmann           6332
# @JoeCz                  5147
# @wawinereport           4966
# @gordone_cellars        4177
# @AnneInVino             3685
# @laurbuzz               1835
# @suskostrzewa           1085
# @worldwineguys          1005
# @bkfiona                  27
# @winewchristina            6

# %%
reviews[['price','points']].set_index('price').sort_index(ascending=True)
# Out:
#        points
# price
# 4.0        85
# 4.0        84
# 4.0        83
# 4.0        84
# 4.0        84
# ...       ...
# NaN        86
# NaN        90
# NaN        90
# NaN        91
# NaN        90
#
# [129971 rows x 1 columns]

# %%
m = reviews[['variety','price']]

# %%
m3 = m['variety'].unique()

# %%
m3
# Out:
# array(['White Blend', 'Portuguese Red', 'Pinot Gris', 'Riesling',
#        'Pinot Noir', 'Tempranillo-Merlot', 'Frappato', 'Gewürztraminer',
#        'Cabernet Sauvignon', 'Nerello Mascalese', 'Chardonnay', 'Malbec',
#        'Tempranillo Blend', 'Meritage', 'Red Blend', 'Merlot',
#        "Nero d'Avola", 'Chenin Blanc', 'Gamay', 'Sauvignon Blanc',
#        'Viognier-Chardonnay', 'Primitivo', 'Catarratto', 'Inzolia',
#        'Petit Verdot', 'Monica', 'Bordeaux-style White Blend', 'Grillo',
#        'Sangiovese', 'Cabernet Franc', 'Champagne Blend',
#        'Bordeaux-style Red Blend', 'Aglianico', 'Petite Sirah',
#        'Touriga Nacional', 'Carmenère', 'Albariño', 'Petit Manseng',
#        'Rosé', 'Zinfandel', 'Vernaccia', 'Rosato', 'Grüner Veltliner',
#        'Viognier', 'Vermentino', 'Grenache Blanc', 'Syrah', 'Nebbiolo',
#        'Shiraz-Cabernet Sauvignon', 'Pinot Blanc', 'Alsace white blend',
#        'Barbera', 'Rhône-style Red Blend', 'Portuguese White', 'Graciano',
# ...

# %%
m7 = []
for i in m3:
    m4 = m[m['variety']==i]['price'].max()
    m7.append(m4)

# %%
m1 = m[m['price']==m['price'].max()][['price','variety']]

# %%
m2 = m1.append(m[m['price']==m['price'].min()][['price','variety']])

# %%
m1['price'].reset_index().max()
# Out:
# C:\Users\Nikhil\AppData\Local\Temp/ipykernel_36936/4070709943.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   m1['price'].reset_index().max()
# price    3300.0
# dtype: float64

# %%
price_extremes = m2.set_index('variety')
# Out:
#                            price
# variety
# Bordeaux-style Red Blend  3300.0
# Syrah                        4.0
# White Blend                  4.0
# Malbec-Syrah                 4.0
# Chardonnay                   4.0
# Chardonnay                   4.0
# Cabernet Sauvignon           4.0
# Merlot                       4.0
# Merlot                       4.0
# Tempranillo                  4.0
# White Blend                  4.0
# Pinot Grigio                 4.0

# %%
m6 = []
for i in m3:
    m5 = m[m['variety']==i]['price'].min()
    m6.append(m5)

# %%
reviews['variety']
# Out:
# 0            White Blend
# 1         Portuguese Red
# 2             Pinot Gris
# 3               Riesling
# 4             Pinot Noir
#                ...
# 129966          Riesling
# 129967        Pinot Noir
# 129968    Gewürztraminer
# 129969        Pinot Gris
# 129970    Gewürztraminer
# Name: variety, Length: 129971, dtype: object

# %%
m6
# Out:
# [4.0,
#  5.0,
#  9.0,
#  5.0,
#  5.0,
#  6.0,
#  13.0,
#  6.0,
#  4.0,
#  10.0,
#  4.0,
#  5.0,
#  7.0,
#  9.0,
#  5.0,
#  4.0,
#  8.0,
#  6.0,
#  9.0,
#  5.0,
#  10.0,
#  5.0,
#  9.0,
#  7.0,
#  12.0,
#  14.0,
#  6.0,
#  8.0,
#  6.0,
#  10.0,
#  7.0,
#  7.0,
#  6.0,
#  8.0,
#  7.0,
#  6.0,
#  10.0,
#  11.0,
#  5.0,
#  5.0,
#  7.0,
#  8.0,
#  9.0,
#  8.0,
#  8.0,
#  17.0,
#  4.0,
#  12.0,
#  5.0,
#  8.0,
#  10.0,
#  10.0,
#  7.0,
#  5.0,
#  10.0,
#  11.0,
#  10.0,
#  12.0,
#  7.0,
#  13.0,
#  8.0,
#  6.0,
#  9.0,
#  14.0,
#  10.0,
#  9.0,
#  5.0,
#  7.0,
#  5.0,
#  6.0,
#  9.0,
#  14.0,
#  9.0,
#  10.0,
#  12.0,
#  17.0,
#  21.0,
#  15.0,
#  9.0,
#  10.0,
#  10.0,
#  5.0,
#  7.0,
#  16.0,
#  12.0,
#  10.0,
#  4.0,
#  4.0,
#  15.0,
#  10.0,
#  8.0,
#  9.0,
#  8.0,
#  9.0,
#  13.0,
#  10.0,
#  9.0,
#  12.0,
#  12.0,
#  18.0,
#  6.0,
#  9.0,
#  11.0,
#  5.0,
#  7.0,
#  10.0,
#  9.0,
#  19.0,
#  10.0,
#  9.0,
#  10.0,
#  11.0,
#  8.0,
#  8.0,
#  18.0,
#  10.0,
#  12.0,
#  8.0,
#  19.0,
# ...

# %%
z1 = []
for i in m3:
    z1.append(i)

# %%
price_extremes = pd.DataFrame(data={'max_price':m7,'min_price':m6},index=z1)
price_extremes
# Out:
#                           max_price  min_price
# White Blend                   375.0        4.0
# Portuguese Red                450.0        5.0
# Pinot Gris                    135.0        9.0
# Riesling                      775.0        5.0
# Pinot Noir                   2500.0        5.0
# ...                             ...        ...
# Pignolo                        70.0       70.0
# Caprettone                     19.0       19.0
# Ondenc                         15.0       15.0
# Athiri                         18.0       18.0
# Bobal-Cabernet Sauvignon        9.0        9.0
#
# [708 rows x 2 columns]

# %%
sorted_varieties_max = price_extremes['max_price'].sort_values(ascending=False)
# Out:
# Bordeaux-style Red Blend          3300.0
# Pinot Noir                        2500.0
# Chardonnay                        2013.0
# Grüner Veltliner                  1100.0
# Bordeaux-style White Blend        1000.0
#                                    ...
# Sauvignon Blanc-Sauvignon Gris       NaN
# NaN                                  NaN
# Vital                                NaN
# Espadeiro                            NaN
# Roscetto                             NaN
# Name: max_price, Length: 708, dtype: float64

# %%
sorted_varieties_min = price_extremes['min_price'].sort_values(ascending=False)
sorted_varieties_min
# Out:
# Ramisco                           495.0
# Terrantez                         236.0
# Francisa                          160.0
# Rosenmuskateller                  150.0
# Tinta Negra Mole                  112.0
#                                   ...
# Sauvignon Blanc-Sauvignon Gris      NaN
# NaN                                 NaN
# Vital                               NaN
# Espadeiro                           NaN
# Roscetto                            NaN
# Name: min_price, Length: 708, dtype: float64

# %%
reviewer_mean_ratings = reviews[['taster_name','points']].set_index('taster_name')
# Out:
#                     points
# taster_name
# Kerin O’Keefe           87
# Roger Voss              87
# Paul Gregutt            87
# Alexander Peartree      87
# Paul Gregutt            87
# ...                    ...
# Anna Lee C. Iijima      90
# Paul Gregutt            90
# Roger Voss              90
# Roger Voss              90
# Roger Voss              90
#
# [129971 rows x 1 columns]

# %%
t1 = reviews['taster_name'].unique()

# %%
t2 = []
for i in t1:
    t2.append(i)

# %%
t4 = []
for i in t1:
    t3 = reviews[reviews['taster_name']==i]['points'].mean()
    t4.append(t3)

# %%
t4
# Out:
# [88.86794729027469,
#  88.70800344908677,
#  89.08256399496433,
#  85.855421686747,
#  86.90749306197965,
#  88.41562853907135,
#  89.21337946943483,
#  90.00868603916614,
#  nan,
#  88.75573902537253,
#  88.62628680871438,
#  88.53623469982514,
#  90.56255088195387,
#  87.73950953678474,
#  89.1011673151751,
#  88.31975560081466,
#  86.60921658986175,
#  86.39568345323741,
#  86.88888888888889,
#  87.83333333333333]

# %%
reviewer_mean_ratings = pd.Series(data=t4,index=t2)

# %%
reviewer_mean_ratings
# Out:
# Kerin O’Keefe         88.867947
# Roger Voss            88.708003
# Paul Gregutt          89.082564
# Alexander Peartree    85.855422
# Michael Schachner     86.907493
# Anna Lee C. Iijima    88.415629
# Virginie Boone        89.213379
# Matt Kettmann         90.008686
# NaN                         NaN
# Sean P. Sullivan      88.755739
# Jim Gordon            88.626287
# Joe Czerwinski        88.536235
# Anne Krebiehl MW      90.562551
# Lauren Buzzeo         87.739510
# Mike DeSimone         89.101167
# Jeff Jenssen          88.319756
# Susan Kostrzewa       86.609217
# Carrie Dykes          86.395683
# Fiona Adams           86.888889
# Christina Pickard     87.833333
# dtype: float64

# %%
v = reviews.groupby('country')['variety'].value_counts()

# %%
country_variety_counts = v.sort_values(ascending=False)
# Out:
# country  variety
# US       Pinot Noir                           9885
#          Cabernet Sauvignon                   7315
#          Chardonnay                           6801
# France   Bordeaux-style Red Blend             4725
# Italy    Red Blend                            3624
#                                               ...
# Spain    Cabernet Sauvignon-Shiraz               1
#          Cabernet Sauvignon-Cabernet Franc       1
#          Cabernet Franc                          1
#          Bobal-Cabernet Sauvignon                1
# Uruguay  White Blend                             1
# Name: variety, Length: 1612, dtype: int64

# %% [markdown]
# # Data Types and Missing values

# %%
dtype = reviews['points'].dtypes
# Out:
# dtype('int64')

# %%
point_strings = reviews['points'].astype('O')
# Out:
# 0         87
# 1         87
# 2         87
# 3         87
# 4         87
#           ..
# 129966    90
# 129967    90
# 129968    90
# 129969    90
# 129970    90
# Name: points, Length: 129971, dtype: object

# %%
n_missing_prices = reviews['price'].isna().sum()
# Out:
# 8996

# %%
reviews['region_1'].value_counts()
# Out:
# Napa Valley                4480
# Columbia Valley (WA)       4124
# Russian River Valley       3091
# California                 2629
# Paso Robles                2350
#                            ...
# Lamezia                       1
# Trentino Superiore            1
# Grave del Friuli              1
# Vin Santo di Carmignano       1
# Paestum                       1
# Name: region_1, Length: 1229, dtype: int64

# %%
h = reviews['region_1'].fillna('Unknown')

# %%
reviews_per_region = h.value_counts()
# Out:
# Unknown                    21247
# Napa Valley                 4480
# Columbia Valley (WA)        4124
# Russian River Valley        3091
# California                  2629
#                            ...
# Lamezia                        1
# Trentino Superiore             1
# Grave del Friuli               1
# Vin Santo di Carmignano        1
# Paestum                        1
# Name: region_1, Length: 1230, dtype: int64

# %% [markdown]
# # Renaming and combining

# %%
renamed = reviews.rename(columns={'region_1':'region','region_2':'locale'})
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reindexed = reviews.set_index('winery')
# Out:
#                                           Unnamed: 0   country  \
# winery
# Nicosia                                            0     Italy
# Quinta dos Avidagos                                1  Portugal
# Rainstorm                                          2        US
# St. Julian                                         3        US
# Sweet Cheeks                                       4        US
# ...                                              ...       ...
# Dr. H. Thanisch (Erben Müller-Burggraef)      129966   Germany
# Citation                                      129967        US
# Domaine Gresser                               129968    France
# Domaine Marcel Deiss                          129969    France
# Domaine Schoffit                              129970    France
#
#                                                                                 description  \
# winery
# Nicosia                                   Aromas include tropical fruit, broom, brimston...
# ...

# %%
pm = pd.read_csv('C:/Users/Nikhil/AppData/Local/Temp/Temp1_openpowerlifting.csv.zip/openpowerlifting.csv')

# %%
pm
# Out:
#         MeetID              Name Sex   Equipment   Age     Division  \
# 0            0  Angie Belk Terry   F       Wraps  47.0    Mst 45-49
# 1            0       Dawn Bogart   F  Single-ply  42.0    Mst 40-44
# 2            0       Dawn Bogart   F  Single-ply  42.0  Open Senior
# 3            0       Dawn Bogart   F         Raw  42.0  Open Senior
# 4            0      Destiny Dula   F         Raw  18.0   Teen 18-19
# ...        ...               ...  ..         ...   ...          ...
# 386409    8481   William Barabas   M   Multi-ply   NaN        Elite
# 386410    8481      Justin Zottl   M   Multi-ply   NaN        Elite
# 386411    8481     Jake Anderson   M   Multi-ply   NaN        Elite
# 386412    8481    Jeff Bumanglag   M   Multi-ply   NaN        Elite
# 386413    8481     Shane Hammock   M   Multi-ply   NaN        Elite
#
#         BodyweightKg WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  \
# 0              59.60            60       NaN        47.63       NaN
# ...

# %%
pc = pd.read_csv('C:/Users/Nikhil/Downloads/meets.csv')

# %%
pc
# Out:
#       MeetID                   MeetPath Federation        Date MeetCountry  \
# 0          0             365strong/1601  365Strong  2016-10-29         USA
# 1          1             365strong/1602  365Strong  2016-11-19         USA
# 2          2             365strong/1603  365Strong  2016-07-09         USA
# 3          3             365strong/1604  365Strong  2016-06-11         USA
# 4          4             365strong/1605  365Strong  2016-04-10         USA
# ...      ...                        ...        ...         ...         ...
# 8477    8477            xpc/2015-finals        XPC  2015-03-06         USA
# 8478    8478  xpc/2016-bench-freak-show        XPC  2016-03-04         USA
# 8479    8479      xpc/2016-elite-finals        XPC  2016-03-04         USA
# 8480    8480        xpc/2016-pro-finals        XPC  2016-03-05         USA
# 8481    8481            xpc/2017-finals        XPC  2017-03-03         USA
#
# ...

# %%
com = pm.merge(pc,on='MeetID')

# %%
com
# Out:
#         MeetID              Name Sex   Equipment   Age     Division  \
# 0            0  Angie Belk Terry   F       Wraps  47.0    Mst 45-49
# 1            0       Dawn Bogart   F  Single-ply  42.0    Mst 40-44
# 2            0       Dawn Bogart   F  Single-ply  42.0  Open Senior
# 3            0       Dawn Bogart   F         Raw  42.0  Open Senior
# 4            0      Destiny Dula   F         Raw  18.0   Teen 18-19
# ...        ...               ...  ..         ...   ...          ...
# 386409    8481   William Barabas   M   Multi-ply   NaN        Elite
# 386410    8481      Justin Zottl   M   Multi-ply   NaN        Elite
# 386411    8481     Jake Anderson   M   Multi-ply   NaN        Elite
# 386412    8481    Jeff Bumanglag   M   Multi-ply   NaN        Elite
# 386413    8481     Shane Hammock   M   Multi-ply   NaN        Elite
#
#         BodyweightKg WeightClassKg  Squat4Kg  BestSquatKg  ...  TotalKg  \
# 0              59.60            60       NaN        47.63  ...   138.35
# ...
